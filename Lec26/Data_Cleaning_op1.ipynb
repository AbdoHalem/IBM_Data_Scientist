# %% [markdown]
# # HW option 1
# * 0- Remove Duplicated Data
# * 1- Normalization (Using MinMaxScaler)
# * 2- Corr
# * 3- Skew
# * 4- Nulls

# %%
import pandas as pd
import numpy as np 

import seaborn as sb 
import matplotlib.pylab as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler    #mean norm (x-mean)/std   2/3 of data in range -1 to 1 and mean =0
from sklearn.preprocessing import MinMaxScaler      #range from 0 to 1

# %% [markdown]
# # First, reading the data

# %%
housing = pd.read_csv("D:\Engineering\IBM_Data_Scientist\Lectures\Lec26\lec19 extra friday\Ames_Housing_Data1.tsv", sep='\t')
housing
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         1  526301100           20        RL         141.0     31770   Pave
# 2         2  526350040           20        RH          80.0     11622   Pave
# 3         3  526351010           20        RL          81.0     14267   Pave
# 4         4  526353030           20        RL          93.0     11160   Pave
# 5         5  527105010           60        RL          74.0     13830   Pave
# 6         6  527105030           60        RL          78.0      9978   Pave
# 7         7  527127150          120        RL          41.0      4920   Pave
# 8         8  527145080          120        RL          43.0      5005   Pave
# 9         9  527146030          120        RL          39.0      5389   Pave
# 10       10  527162130           60        RL          60.0      7500   Pave
# ...

# %% [markdown]
# # 0- Remove duplicated data

# %%
housing = housing.drop_duplicates()
housing.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 2      2  526350040           20        RH          80.0     11622   Pave
# 3      3  526351010           20        RL          81.0     14267   Pave
# 4      4  526353030           20        RL          93.0     11160   Pave
# 5      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour    ...     Pool Area Pool QC  Fence  \
# 0   NaN       IR1          Lvl    ...             0     NaN    NaN
# 2   NaN       Reg          Lvl    ...             0     NaN  MnPrv
# 3   NaN       IR1          Lvl    ...             0     NaN    NaN
# 4   NaN       Reg          Lvl    ...             0     NaN    NaN
# 5   NaN       IR1          Lvl    ...             0     NaN  MnPrv
#
#   Misc Feature Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %% [markdown]
# # 1- Normalize the data (use min-max scaler)

# %%
# Get the numerical data only from housing DataFrame
housing_numerical = housing.select_dtypes(include= ['float64', 'int64'])
housing_numerical.head()
# Out:
#    Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      1  526301100           20         141.0     31770             6
# 2      2  526350040           20          80.0     11622             5
# 3      3  526351010           20          81.0     14267             6
# 4      4  526353030           20          93.0     11160             7
# 5      5  527105010           60          74.0     13830             5
#
#    Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area    ...      \
# 0             5        1960            1960         112.0    ...
# 2             6        1961            1961           0.0    ...
# 3             6        1958            1958         108.0    ...
# 4             5        1968            1968           0.0    ...
# 5             5        1997            1998           0.0    ...
#
#    Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# ...

# %%
# Normalize the numerical data in the DataFrame
housing_normalized = housing.copy()
housing_normalized[housing_numerical.columns] = MinMaxScaler().fit_transform(housing_normalized[housing_numerical.columns])
housing_normalized.head()
# Out:
#       Order       PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  0.000000  0.000000     0.000000        RL      0.410959  0.142420   Pave
# 2  0.000341  0.000102     0.000000        RH      0.202055  0.048246   Pave
# 3  0.000683  0.000104     0.000000        RL      0.205479  0.060609   Pave
# 4  0.001024  0.000108     0.000000        RL      0.246575  0.046087   Pave
# 5  0.001366  0.001672     0.235294        RL      0.181507  0.058566   Pave
#
#   Alley Lot Shape Land Contour    ...     Pool Area Pool QC  Fence  \
# 0   NaN       IR1          Lvl    ...           0.0     NaN    NaN
# 2   NaN       Reg          Lvl    ...           0.0     NaN  MnPrv
# 3   NaN       IR1          Lvl    ...           0.0     NaN    NaN
# 4   NaN       Reg          Lvl    ...           0.0     NaN    NaN
# 5   NaN       IR1          Lvl    ...           0.0     NaN  MnPrv
#
#   Misc Feature  Misc Val   Mo Sold Yr Sold Sale Type  Sale Condition  \
# ...

# %% [markdown]
# # 2- Get correlation between columns

# %%
# Show correlation and outliers first by data visualization
plt.figure(figsize = [25, 35])
for i in range(len(housing_numerical.columns)): #range 0 to 38
    plt.subplot(10, 4, 1+i)
    sb.regplot(data = housing_numerical, x = housing_numerical.columns[i], y = 'SalePrice');
    plt.xlabel(housing_numerical.columns[i]);
    plt.ylabel('SalePrice');

# %%
# Calculate corelation between every column and 'SalePrice' column
housing_numerical_corr = housing_numerical.corr()['SalePrice']
housing_numerical_corr
# Out:
# Order             -0.031408
# PID               -0.246521
# MS SubClass       -0.085092
# Lot Frontage       0.357318
# Lot Area           0.266549
# Overall Qual       0.799262
# Overall Cond      -0.101697
# Year Built         0.558426
# Year Remod/Add     0.532974
# Mas Vnr Area       0.508285
# BsmtFin SF 1       0.432914
# BsmtFin SF 2       0.005891
# Bsmt Unf SF        0.182855
# Total Bsmt SF      0.632280
# 1st Flr SF         0.621676
# 2nd Flr SF         0.269373
# Low Qual Fin SF   -0.037660
# Gr Liv Area        0.706780
# Bsmt Full Bath     0.276050
# Bsmt Half Bath    -0.035835
# Full Bath          0.545604
# Half Bath          0.285056
# Bedroom AbvGr      0.143913
# Kitchen AbvGr     -0.119814
# TotRms AbvGrd      0.495474
# Fireplaces         0.474558
# Garage Yr Blt      0.526965
# Garage Cars        0.647877
# Garage Area        0.640401
# Wood Deck SF       0.327143
# Open Porch SF      0.312951
# Enclosed Porch    -0.128787
# 3Ssn Porch         0.032225
# ...

# %%
high_corr_features = housing_numerical_corr[abs(housing_numerical_corr) > 0.5].sort_values(ascending=False)
high_corr_features
# Out:
# SalePrice         1.000000
# Overall Qual      0.799262
# Gr Liv Area       0.706780
# Garage Cars       0.647877
# Garage Area       0.640401
# Total Bsmt SF     0.632280
# 1st Flr SF        0.621676
# Year Built        0.558426
# Full Bath         0.545604
# Year Remod/Add    0.532974
# Garage Yr Blt     0.526965
# Mas Vnr Area      0.508285
# Name: SalePrice, dtype: float64

# %% [markdown]
# # 3- Handling Null Values Before SHowing Skewness

# %%
housing_normalized[high_corr_features.index].isnull().sum()
# Out:
# SalePrice           0
# Overall Qual        0
# Gr Liv Area         0
# Garage Cars         1
# Garage Area         1
# Total Bsmt SF       1
# 1st Flr SF          0
# Year Built          0
# Full Bath           0
# Year Remod/Add      0
# Garage Yr Blt     159
# Mas Vnr Area       23
# dtype: int64

# %%
# Replace nan values with mean of its column
column = housing_normalized[high_corr_features.index]
housing_normalized[high_corr_features.index] = column.fillna(column.mean())
housing_normalized[high_corr_features.index].isnull().sum()
# Out:
# SalePrice         0
# Overall Qual      0
# Gr Liv Area       0
# Garage Cars       0
# Garage Area       0
# Total Bsmt SF     0
# 1st Flr SF        0
# Year Built        0
# Full Bath         0
# Year Remod/Add    0
# Garage Yr Blt     0
# Mas Vnr Area      0
# dtype: int64

# %% [markdown]
# # 4- Handling Skewed Data

# %%
plt.figure(figsize=[20,20])
for i in range(0, len(high_corr_features)):
    plt.subplot(4, 3, i+1)
    column = housing_normalized[high_corr_features.index[i]]
    # column = column.fillna(column.mean())   # Replace nan values with mean of its column to use sb.distplot() successfully
    sb.distplot(column)
    plt.title(column.skew())

# %%
# Use log tranform to reduce the skewness of the data
plt.figure(figsize=[20,20])
for i in range(0, len(high_corr_features)):
    plt.subplot(4, 3, i+1)
    column = housing_normalized[high_corr_features.index[i]]
    # column = column.fillna(column.mean())   # Replace nan values with mean of its column to use sb.distplot() successfully
    if(abs(column.skew()) > 0.5):
        # housing_normalized[high_corr_features.index[i]] = np.log(housing_normalized[high_corr_features.index[i]])
        column = np.log1p(housing_normalized[high_corr_features.index[i]])      # Use log(x+1) to take log(x=0) without errors
        housing_normalized[high_corr_features.index[i]] = column                # Update the DataFrame
        
    sb.distplot(column)
    plt.title(column.skew())

# %% [markdown]
# # 5- Handling Null Values in the Whole Dataset After Normalization and Handling Skewed Data

# %%
null_columns = housing_normalized.isnull().sum().sort_values(ascending=False)[0:22]
null_columns
# Out:
# Pool QC           2917
# Misc Feature      2824
# Alley             2732
# Fence             2358
# Fireplace Qu      1422
# Lot Frontage       490
# Garage Qual        159
# Garage Finish      159
# Garage Cond        159
# Garage Type        157
# Bsmt Exposure       83
# BsmtFin Type 2      81
# Bsmt Qual           80
# BsmtFin Type 1      80
# Bsmt Cond           80
# Mas Vnr Type        23
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Electrical           1
# Bsmt Unf SF          1
# BsmtFin SF 2         1
# BsmtFin SF 1         1
# dtype: int64

# %%
# Drop first five columns in null_columns because they are useless as they have a huge number of null values
housing_normalized = housing_normalized.drop(null_columns.index[0:5], axis=1)
housing_normalized.head()
# Out:
#       Order       PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  0.000000  0.000000     0.000000        RL      0.410959  0.142420   Pave
# 2  0.000341  0.000102     0.000000        RH      0.202055  0.048246   Pave
# 3  0.000683  0.000104     0.000000        RL      0.205479  0.060609   Pave
# 4  0.001024  0.000108     0.000000        RL      0.246575  0.046087   Pave
# 5  0.001366  0.001672     0.235294        RL      0.181507  0.058566   Pave
#
#   Lot Shape Land Contour Utilities    ...     Enclosed Porch 3Ssn Porch  \
# 0       IR1          Lvl    AllPub    ...                0.0        0.0
# 2       Reg          Lvl    AllPub    ...                0.0        0.0
# 3       IR1          Lvl    AllPub    ...                0.0        0.0
# 4       Reg          Lvl    AllPub    ...                0.0        0.0
# 5       IR1          Lvl    AllPub    ...                0.0        0.0
#
#   Screen Porch Pool Area  Misc Val   Mo Sold Yr Sold  Sale Type  \
# ...

# %%
null_columns = housing_normalized.isnull().sum().sort_values(ascending=False)[0:17]
# for i in null_columns.index:
#     print(i)
null_columns
# Out:
# Lot Frontage      490
# Garage Cond       159
# Garage Finish     159
# Garage Qual       159
# Garage Type       157
# Bsmt Exposure      83
# BsmtFin Type 2     81
# BsmtFin Type 1     80
# Bsmt Cond          80
# Bsmt Qual          80
# Mas Vnr Type       23
# Bsmt Half Bath      2
# Bsmt Full Bath      2
# Electrical          1
# Bsmt Unf SF         1
# BsmtFin SF 2        1
# BsmtFin SF 1        1
# dtype: int64

# %%
for i in null_columns.index:
    print(housing_normalized[i].dtype)
# Out:
# float64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# float64
# float64
# object
# float64
# float64
# float64

# %%
# print(housing_normalized[null_columns.index])

for i in null_columns.index:
    # print(housing_normalized[i].dtype)
    print(housing_normalized[i].dtype == object)
# Out:
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# False
# False
# False

# %%
# Replace nan numerical values with mean of its columns and drop string nan values
for i in null_columns.index:
    if(housing_normalized[i].dtype != object):
        mean = housing_normalized[i].mean()
        housing_normalized[i].fillna(mean, inplace= True)
    else:
        housing_normalized.dropna(subset=[i], inplace=True)

# %%
housing_normalized.isnull().sum().sum()
# Out:
# 0
